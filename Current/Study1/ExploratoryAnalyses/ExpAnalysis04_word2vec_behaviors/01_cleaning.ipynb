# %% [markdown]
# # Aim
# In our study (Study 1), we could not find any statistical significances.
#
# In this exploratory analysis, we computed document simirarities between the self and target conditions based on word vectors from Word2vec.
#
# First, as in Exploratory Analysis 01, we excluded data based on the apperanace frequency of the response.

# %% [markdown]
# # Load data

# %%
import pandas as pd

# %%
# Load the raw data
df = pd.read_excel('../../RawData/RawData_230519to230522.xlsx', sheet_name=1, header=0, index_col=0)

# %%
# Rename variables
var_df = pd.read_excel('../../Materials/variables.xlsx', sheet_name=1, header=0, index_col=None)
var_dict = dict(zip(var_df['name1'], var_df['name2']))
df = df.rename(columns=var_dict)

# %%
df.head()
# Out:
#                    start                  end        rt  self_sex  self_age  \
# MID
# 1    2023/05/19-12:49:32  2023/05/19-12:51:56  00:02:24         2        50
# 2    2023/05/19-12:49:10  2023/05/19-12:52:07  00:02:57         1        40
# 3    2023/05/19-12:49:28  2023/05/19-12:55:05  00:05:37         2        40
# 4    2023/05/19-12:55:11  2023/05/19-12:57:07  00:01:56         1        48
# 5    2023/05/19-12:54:24  2023/05/19-12:57:31  00:03:07         1        46
#
#      residence  participation  IOS_score  target_likedislike  target_sex  ...  \
# MID                                                                       ...
# 1           13              1          6                   1           2  ...
# 2            7              1          5                   2           2  ...
# 3           23              1          2                   2           1  ...
# 4           39              1          1                   3           2  ...
# 5           18              1          2                   3           1  ...
#
#      target_responsibility_score target_responsibility_text  \
# MID
# 1                              3                       回答なし
# 2                              3                       回答なし
# 3                              2                    仕事を抱え込む
# 4                              4                       回答なし
# 5                              4                         ない
#
#      target_carefulness_score target_carefulness_text  \
# MID
# 1                           5                    回答なし
# 2                           3                    回答なし
# 3                           7                チェックが細かい
# 4                           4                    回答なし
# 5                           4                      ない
#
#      target_activeness_score target_activeness_text  target_sociability_score  \
# MID
# 1                          7                   回答なし                         7
# 2                          3                   回答なし                         4
# 3                          7                  基本受け身                         2
# 4                          4                   回答なし                         4
# 5                          3                     なし                         4
#
#     target_sociability_text  completion stratumID
# MID
# 1                      回答なし        COMP         6
# 2                      回答なし        COMP         5
# 3                      話が下手        COMP         2
# 4                      回答なし        COMP         1
# 5                        なし        COMP         2
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1 to 182
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   start                        182 non-null    object
#  1   end                          182 non-null    object
#  2   rt                           182 non-null    object
#  3   self_sex                     182 non-null    int64
#  4   self_age                     182 non-null    int64
#  5   residence                    182 non-null    int64
#  6   participation                182 non-null    int64
#  7   IOS_score                    182 non-null    int64
#  8   target_likedislike           182 non-null    int64
#  9   target_sex                   182 non-null    int64
#  10  target_age                   182 non-null    int64
#  11  relationship                 182 non-null    object
#  12  self_tolerance_score         182 non-null    int64
#  13  self_tolerance_text          182 non-null    object
#  14  self_pleasantness_score      182 non-null    int64
#  15  self_pleasantness_text       182 non-null    object
#  16  self_responsibility_score    182 non-null    int64
#  17  self_responsibility_text     182 non-null    object
#  18  self_carefulness_score       182 non-null    int64
#  19  self_carefulness_text        182 non-null    object
#  20  self_activeness_score        182 non-null    int64
#  21  self_activeness_text         182 non-null    object
#  22  self_sociability_score       182 non-null    int64
#  23  self_sociability_text        182 non-null    object
#  24  target_tolerance_score       182 non-null    int64
#  25  target_tolerance_text        182 non-null    object
#  26  target_pleasantness_score    182 non-null    int64
#  27  target_pleasantness_text     182 non-null    object
#  28  target_responsibility_score  182 non-null    int64
#  29  target_responsibility_text   182 non-null    object
#  30  target_carefulness_score     182 non-null    int64
#  31  target_carefulness_text      182 non-null    object
#  32  target_activeness_score      182 non-null    int64
#  33  target_activeness_text       182 non-null    object
#  34  target_sociability_score     182 non-null    int64
#  35  target_sociability_text      182 non-null    object
#  36  completion                   182 non-null    object
#  37  stratumID                    182 non-null    int64
# dtypes: int64(21), object(17)
# memory usage: 55.5+ KB

# %% [markdown]
# # Data exclusion
# We expected that the most frequent responses are meaningless, e.g., "回答なし" or "わからない". So, we tried to excluded those responses based on their apperance frequency.
# - step1: Examines the most frequent responses
# - step2: Replaces the frequent responses with a whitespace
# - step3: Excludes participants whose responses are all whitespaces

# %%
textvar_name = ['self_tolerance_text', 'self_pleasantness_text', 'self_responsibility_text',
		'self_carefulness_text', 'self_activeness_text', 'self_sociability_text',
		'target_tolerance_text', 'target_pleasantness_text', 'target_responsibility_text',
		'target_carefulness_text', 'target_activeness_text', 'target_sociability_text',
		]

# %% [markdown]
# ## Step1: Examines the most frequent responses

# %%
s_concat = pd.Series(dtype=object)
for col in textvar_name:
	s_concat = pd.concat([s_concat, df.loc[:, col]], ignore_index=True)

# %%
s_concat.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2184 entries, 0 to 2183
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 2184 non-null   object
# dtypes: object(1)
# memory usage: 17.2+ KB

# %%
s_concat
# Out:
# 0                                            回答なし
# 1                                            回答なし
# 2                                        怒ったことがない
# 3                                            回答なし
# 4                                              ない
#                           ...
# 2179                                        わからない
# 2180                                           なし
# 2181                                           なし
# 2182                                         回答なし
# 2183    人込みは嫌いと言いながら出掛けたがる、近所の人や会社の人に積極的に挨拶して会話する
# Length: 2184, dtype: object

# %%
s_concat.value_counts().head(30)
# Out:
# 回答なし           1063
# なし              257
# ない               58
# わからない            50
# 特になし             26
# なんとなく            23
# 無し               23
# 回答無し             19
# 特に無し             17
# 特にありません。         17
# 不明               12
# 楽しい              12
# 特に無い             12
# 意味不明              9
# 良い                6
# ないですね             5
# 特無し               3
# かし                3
# 無い                3
# 普通                3
# 自分勝手              2
# 回答なし              2
# エピソードなし           2
# 行動力がある            2
# 外面がいい             2
# どちらでもないと思う。       2
# 何事も慎重             2
# 石橋を叩きすぎる          2
# 分からない             2
# 熟慮するため            2
# Name: count, dtype: int64

# %%
# rep_list = list(s_concat.value_counts()[s_concat.value_counts() > 10].index) # 頻出回数 > 10
rep_list = list(s_concat.value_counts()[0:20].index) # 頻出上位20語
print(rep_list)
# Out:
# ['回答なし', 'なし', 'ない', 'わからない', '特になし', 'なんとなく', '無し', '回答無し', '特に無し', '特にありません。', '不明', '楽しい', '特に無い', '意味不明', '良い', 'ないですね', '特無し', 'かし', '無い', '普通']

# %% [markdown]
# ## Steps 2 and 3: Replaces the responses and excludes the records

# %%
df2 = df.replace(rep_list, '').drop_duplicates(subset=textvar_name, keep=False)

# %% [markdown]
# ## Check the remaining records

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88 entries, 2 to 182
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   start                        88 non-null     object
#  1   end                          88 non-null     object
#  2   rt                           88 non-null     object
#  3   self_sex                     88 non-null     int64
#  4   self_age                     88 non-null     int64
#  5   residence                    88 non-null     int64
#  6   participation                88 non-null     int64
#  7   IOS_score                    88 non-null     int64
#  8   target_likedislike           88 non-null     int64
#  9   target_sex                   88 non-null     int64
#  10  target_age                   88 non-null     int64
#  11  relationship                 88 non-null     object
#  12  self_tolerance_score         88 non-null     int64
#  13  self_tolerance_text          88 non-null     object
#  14  self_pleasantness_score      88 non-null     int64
#  15  self_pleasantness_text       88 non-null     object
#  16  self_responsibility_score    88 non-null     int64
#  17  self_responsibility_text     88 non-null     object
#  18  self_carefulness_score       88 non-null     int64
#  19  self_carefulness_text        88 non-null     object
#  20  self_activeness_score        88 non-null     int64
#  21  self_activeness_text         88 non-null     object
#  22  self_sociability_score       88 non-null     int64
#  23  self_sociability_text        88 non-null     object
#  24  target_tolerance_score       88 non-null     int64
#  25  target_tolerance_text        88 non-null     object
#  26  target_pleasantness_score    88 non-null     int64
#  27  target_pleasantness_text     88 non-null     object
#  28  target_responsibility_score  88 non-null     int64
#  29  target_responsibility_text   88 non-null     object
#  30  target_carefulness_score     88 non-null     int64
#  31  target_carefulness_text      88 non-null     object
#  32  target_activeness_score      88 non-null     int64
#  33  target_activeness_text       88 non-null     object
#  34  target_sociability_score     88 non-null     int64
#  35  target_sociability_text      88 non-null     object
#  36  completion                   88 non-null     object
#  37  stratumID                    88 non-null     int64
# dtypes: int64(21), object(17)
# memory usage: 26.8+ KB

# %%
df2.loc[:, textvar_name].head(10)
# Out:
#             self_tolerance_text     self_pleasantness_text  \
# MID
# 2                                                    愛想がない
# 3                      怒ったことがない                   よく道を聞かれる
# 5                                                 遊んでいて楽しい
# 8
# 9
# 11
# 13
# 17            相手が悪気がなかったら仕方ないので           別け隔てなく接してるつもりなので
# 22
# 28   基本怒らないけど、人並みにイライラしたりはするから。  苦手な相手とかにはそっけなくしてしまったりするから
#
#     self_responsibility_text self_carefulness_text self_activeness_text  \
# MID
# 2
# 3                 世話好きでリーダー肌              計画する前に動く               行動力がある
# 5
# 8
# 9
# 11                                                          どちらでもないと思う。
# 13       やらなくてはいけないことはきちんとやる            軽率とは思わないので
# 17              最後までやり遂げたいので        考えて行動してるつもりなので             なるべく動くので
# 22                                  何かを買うときに入念に調べる
# 28      仕事の面などでも責任をもってやりきるから  そこまで軽率な行動をとった記憶はないから   人付き合いの面では特に消極的だと思う
#
#                 self_sociability_text target_tolerance_text  \
# MID
# 2
# 3                              友達がいない                  怒らない
# 5
# 8                                                     回答なし
# 9                どちらかというと自分から話しかけるから。
# 11                            普通だと思う。
# 13                      人の輪に入っていくのは苦手
# 17                     色々な人と仲良くなりたいので             ミスを許してくれる
# 22                                                 すぐにかっとなる
# 28   そこまで知らない人がいる食事会などでは、帰りたくなってしまうから
#
#     target_pleasantness_text target_responsibility_text  \
# MID
# 2
# 3                  優しそうでお人好し                    仕事を抱え込む
# 5
# 8
# 9
# 11                            仕事に関してはあると思うけれどそれ以外はどうだか？
# 13           態度がとても悪い時は感じが悪い
# 17                 人当たりがよいので                   言ったことを守る
# 22             初めて会う人には感じが良い                  仕事を絶対休まない
# 28
#
#     target_carefulness_text         target_activeness_text  \
# MID
# 2
# 3                  チェックが細かい                          基本受け身
# 5
# 8
# 9
# 11                           自分のやりたいことには積極的ですが、家のことはほぼしない。
# 13                                           新しい事はしたがらないので
# 17                考えて行動するので                       行動がはやいので
# 22       何かを買うときに入念に調べてから買う              自分から話しかけることはほぼしない
# 28
#
#     target_sociability_text
# MID
# 2
# 3                      話が下手
# 5
# 8
# 9
# 11    一緒に出かけた先で人と接するのは私だから。
# 13                  人見知りなので
# 17                 明るい性格なので
# 22                人と会うことがない
# 28

# %%
s_concat2 = pd.Series(dtype=object)
for col in textvar_name:
	s_concat2 = pd.concat([s_concat2, df2.loc[:, col]], ignore_index=True)

# %%
s_concat2.value_counts().head(30)
# Out:
#                               493
# 外面がいい                           2
# どちらとも言えない                       2
# 日々の言動からそう思う                     2
# 人見知り                            2
# 石橋を叩きすぎる                        2
# 行動力がある                          2
# どちらでもないと思う。                     2
# 自分勝手                            2
# 親から当たられる                        2
# 回答なし                            2
# 事柄によって変わるから                     2
# 熟慮するため                          2
# 何事も慎重                           2
# 人といると疲れやすくなったから                 2
# 分からない                           2
# 仕事柄                             2
# エピソードなし                         2
# なはさ                             2
# 優しくておおらか                        1
# 一方的                             1
# 言ったことを守る                        1
# 仕事に関してはあると思うけれどそれ以外はどうだか？       1
# 仕事を抱え込む                         1
# 外面は良いが、ずっと一緒にいるとずるい人間だと分かる      1
# 外面は良いと                          1
# ワガママ                            1
# 誰に対しても優しい                       1
# 気が強い                            1
# 全く愛想がない                         1
# Name: count, dtype: int64

# %%
'回答なし' in s_concat2.values
# Out:
# False

# %%
'どちらとも言えない' in s_concat2.values
# Out:
# True

# %% [markdown]
# ## Completion ratio

# %%
print('Num. of Original Samples: ' + str(len(df)))
print('Num. of Excluded Samples: ' + str(len(df) - len(df2)))
print('Num. of Remaining Samples: ' + str(len(df2)))
print('Completion Ratio: ' + str(len(df2) / len(df)))
# Out:
# Num. of Original Samples: 182
# Num. of Excluded Samples: 94
# Num. of Remaining Samples: 88
# Completion Ratio: 0.4835164835164835

# %% [markdown]
# # Output
# Save:
# - Text data as txt
# - Data Frame as xlsx

# %% [markdown]
# ## Text Data

# %%
text_vars_self = [
	'self_tolerance_text',
	'self_pleasantness_text',
	'self_responsibility_text',
	'self_carefulness_text',
	'self_activeness_text',
	'self_sociability_text']

text_vars_target = [
	'target_tolerance_text',
	'target_pleasantness_text',
	'target_responsibility_text',
	'target_carefulness_text',
	'target_activeness_text',
	'target_sociability_text']

# %%
text_vars_all = text_vars_self + text_vars_target

# %%
df2.loc[:, text_vars_all].head()
# Out:
#     self_tolerance_text self_pleasantness_text self_responsibility_text  \
# MID
# 2                                        愛想がない
# 3              怒ったことがない               よく道を聞かれる               世話好きでリーダー肌
# 5                                     遊んでいて楽しい
# 8
# 9
#
#     self_carefulness_text self_activeness_text self_sociability_text  \
# MID
# 2
# 3                計画する前に動く               行動力がある                友達がいない
# 5
# 8
# 9                                               どちらかというと自分から話しかけるから。
#
#     target_tolerance_text target_pleasantness_text target_responsibility_text  \
# MID
# 2
# 3                    怒らない                優しそうでお人好し                    仕事を抱え込む
# 5
# 8                   回答なし
# 9
#
#     target_carefulness_text target_activeness_text target_sociability_text
# MID
# 2
# 3                  チェックが細かい                  基本受け身                    話が下手
# 5
# 8
# 9

# %%
filename = './output01_all.txt'
with open(filename, 'w') as f:
	df2_string = df2.loc[:, text_vars_all].to_string(header=True, index=True)
	f.write(df2_string)

# %%
filename = './output01_self.txt'
with open(filename, 'w') as f:
	df2_string = df2.loc[:, text_vars_self].to_string(header=True, index=True)
	f.write(df2_string)

# %%
filename = './output01_target.txt'
with open(filename, 'w') as f:
	df2_string = df2.loc[:, text_vars_target].to_string(header=True, index=True)
	f.write(df2_string)

# %% [markdown]
# ## Data Frame

# %%
df2.drop(text_vars_all, axis='columns', inplace=True)
df2.head()
# Out:
#                    start                  end        rt  self_sex  self_age  \
# MID
# 2    2023/05/19-12:49:10  2023/05/19-12:52:07  00:02:57         1        40
# 3    2023/05/19-12:49:28  2023/05/19-12:55:05  00:05:37         2        40
# 5    2023/05/19-12:54:24  2023/05/19-12:57:31  00:03:07         1        46
# 8    2023/05/19-12:57:23  2023/05/19-13:00:14  00:02:51         2        39
# 9    2023/05/19-12:55:51  2023/05/19-13:01:43  00:05:52         1        49
#
#      residence  participation  IOS_score  target_likedislike  target_sex  ...  \
# MID                                                                       ...
# 2            7              1          5                   2           2  ...
# 3           23              1          2                   2           1  ...
# 5           18              1          2                   3           1  ...
# 8           13              1          7                   4           2  ...
# 9           13              1          1                   4           2  ...
#
#      self_activeness_score self_sociability_score  target_tolerance_score  \
# MID
# 2                        2                      2                       5
# 3                        1                      2                       1
# 5                        4                      4                       3
# 8                        7                      1                       7
# 9                        3                      5                       3
#
#      target_pleasantness_score  target_responsibility_score  \
# MID
# 2                            5                            3
# 3                            7                            2
# 5                            5                            4
# 8                            5                            7
# 9                            2                            2
#
#      target_carefulness_score  target_activeness_score  \
# MID
# 2                           3                        3
# 3                           7                        7
# 5                           4                        3
# 8                           4                        7
# 9                           4                        3
#
#      target_sociability_score  completion  stratumID
# MID
# 2                           4        COMP          5
# 3                           2        COMP          2
# 5                           4        COMP          2
# 8                           1        COMP         14
# 9                           5        COMP          8
#
# [5 rows x 26 columns]

# %%
df2.columns
# Out:
# Index(['start', 'end', 'rt', 'self_sex', 'self_age', 'residence',
#        'participation', 'IOS_score', 'target_likedislike', 'target_sex',
#        'target_age', 'relationship', 'self_tolerance_score',
#        'self_pleasantness_score', 'self_responsibility_score',
#        'self_carefulness_score', 'self_activeness_score',
#        'self_sociability_score', 'target_tolerance_score',
#        'target_pleasantness_score', 'target_responsibility_score',
#        'target_carefulness_score', 'target_activeness_score',
#        'target_sociability_score', 'completion', 'stratumID'],
#       dtype='object')

# %%
filename = './output01_all.csv'
df2.to_csv(filename, index=True)

# %%
len(df2)
# Out:
# 88

# %%
df2.groupby('IOS_score').size()
# Out:
# IOS_score
# 1     7
# 2    16
# 3    16
# 4     8
# 5    13
# 6    11
# 7    17
# dtype: int64
