# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from ydata_profiling import ProfileReport
from mpl_toolkits.mplot3d import Axes3D

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import scipy.stats as stats
from scipy.linalg import inv
from scipy.spatial import distance

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.multivariate.manova import MANOVA
from statsmodels.tools.sm_exceptions import ConvergenceWarning

from sklearn.preprocessing import StandardScaler

import pingouin as pg

# %%
import statsmodels
print(statsmodels.__version__)
# Out:
# 0.14.0

# %% [markdown]
# # Laod Data

# %%
filename = './Results/output02.csv'
df = pd.read_csv(filename, header=0, index_col=0)
df.head()
# Out:
#         rt  self_sex  self_age  target_likedislike  target_sex  IOS_score  \
# MID
# 2    193.0         1        45                   3           2          5
# 5    137.0         1        36                   4           2          2
# 7    293.0         1        54                   1           2          5
# 8    103.0         1        36                   1           2          1
# 11   160.0         1        56                   1           2          2
#
#     IOS_group  Adj_cosine  Adj_euclidean  Adj_manhattan  Verb_cosine  \
# MID
# 2     HighIOS         NaN            NaN            NaN          NaN
# 5      LowIOS         NaN            NaN            NaN     0.933851
# 7     HighIOS    0.489526        0.77925       4.465907     0.826740
# 8      LowIOS         NaN            NaN            NaN          NaN
# 11     LowIOS         NaN            NaN            NaN          NaN
#
#      Verb_euclidean  Verb_manhattan  Noun_cosine  Noun_euclidean  \
# MID
# 2               NaN             NaN          NaN             NaN
# 5          0.344139        1.932724     0.882830        0.469692
# 7          0.433577        2.556113     0.035336        1.129285
# 8               NaN             NaN     0.397660        1.097579
# 11              NaN             NaN          NaN             NaN
#
#      Noun_manhattan
# MID
# 2               NaN
# 5          2.609289
# 7          6.480907
# 8          6.200497
# 11              NaN

# %%
df.isnull().sum()
# Out:
# rt                      0
# self_sex                0
# self_age                0
# target_likedislike      0
# target_sex              0
# IOS_score               0
# IOS_group               0
# Adj_cosine            184
# Adj_euclidean         184
# Adj_manhattan         184
# Verb_cosine           152
# Verb_euclidean        152
# Verb_manhattan        152
# Noun_cosine           157
# Noun_euclidean        157
# Noun_manhattan        157
# dtype: int64

# %% [markdown]
# # Create a Dataset for Cosine Similarity

# %%
# Remove some columns to create a new dataframe
df_cosine = df.drop(columns=['Adj_euclidean', 'Adj_manhattan',
                             'Verb_euclidean', 'Verb_manhattan',
                             'Noun_euclidean', 'Noun_manhattan',
                             'Noun_cosine'])
df_cosine.head()
# Out:
#         rt  self_sex  self_age  target_likedislike  target_sex  IOS_score  \
# MID
# 2    193.0         1        45                   3           2          5
# 5    137.0         1        36                   4           2          2
# 7    293.0         1        54                   1           2          5
# 8    103.0         1        36                   1           2          1
# 11   160.0         1        56                   1           2          2
#
#     IOS_group  Adj_cosine  Verb_cosine
# MID
# 2     HighIOS         NaN          NaN
# 5      LowIOS         NaN     0.933851
# 7     HighIOS    0.489526     0.826740
# 8      LowIOS         NaN          NaN
# 11     LowIOS         NaN          NaN

# %% [markdown]
# # Missing Values

# %%
# The number of rows in the df_cosine
num_rows = len(df_cosine)
# The number of rows with missing value(s)
num_rows_nan = df_cosine.isnull().any(axis=1).sum()
# The percentage of rows with missing value(s)
percentage_rows_nan = num_rows_nan / num_rows * 100
# Print
print(f"Number of rows: {num_rows}")
print(f"Number of rows with missing value(s): {num_rows_nan}")
print(f"Percentage of missing data: {percentage_rows_nan}")
# Out:
# Number of rows: 403
# Number of rows with missing value(s): 209
# Percentage of missing data: 51.86104218362283

# %%
# Add a new columne to the df_cosine dataframe to indicate the missing values
df_cosine['missing'] = df_cosine.isnull().any(axis=1)

# %% [markdown]
# ## Inspection of the Missing Values

# %%
# Load the data into a pandas dataframe
sentences_token_both = pd.read_csv('./Results/sentences_token_both.csv', header=0, index_col=0)
sentences_token_both.head()
# Out:
#          Adj_self                                          Verb_self  \
# MID
# 2              []                                             ['回答']
# 5              []                                       ['見る', '言う']
# 7    ['直ぐ', '慎重']  ['許す', '聞く', '仕事', 'なる', '落とす', '進める', '飲む', '...
# 8              []                                                 []
# 11   ['普通', 'ない']                           ['いう', '守る', '排除', 'する']
#
#                                   Noun_self  \
# MID
# 2                                     ['梨']
# 5                                    ['文句']
# 7    ['人', '道', '休暇', '気', 'たま', '物', '物事']
# 8                                    ['かし']
# 11                        ['人', '社交', '他者']
#
#                                    Adj_target  \
# MID
# 2                                          []
# 5                                ['悪い', 'ない']
# 7    ['直ぐ', '優しい', '真面目', '勤勉', '大人しい', '好き']
# 8                                          []
# 11                                         []
#
#                                 Verb_target   Noun_target
# MID
# 2                                        []            []
# 5    ['見かける', '見る', '言う', '見る', '許す', '反応']  ['愛想', '文句']
# 7                        ['怒る', '許す', 'する']      ['インドア']
# 8                                        []       ['ふつう']
# 11                                       []            []

# %%
# Define a function to convert a string to a list of tokens
def string_to_tokens(string):
    # remove the square brackets
    if string == '[]':
        return []
    else:
        string = string[1:-1]
    # remove the single quotes
    string = string.replace("'", "")
    # split the string by a comma into a list of tokens
    return string.split(", ")

# Create a new dataframe with each cell containing a list of tokens
sentences_token_both = sentences_token_both.applymap(string_to_tokens)
sentences_token_both.head()
# Out:
# /tmp/ipykernel_1179/3674780812.py:14: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sentences_token_both = sentences_token_both.applymap(string_to_tokens)
#      Adj_self                           Verb_self                 Noun_self  \
# MID
# 2          []                                [回答]                       [梨]
# 5          []                            [見る, 言う]                      [文句]
# 7    [直ぐ, 慎重]  [許す, 聞く, 仕事, なる, 落とす, 進める, 飲む, 嫌う]  [人, 道, 休暇, 気, たま, 物, 物事]
# 8          []                                  []                      [かし]
# 11   [普通, ない]                    [いう, 守る, 排除, する]               [人, 社交, 他者]
#
#                        Adj_target                 Verb_target Noun_target
# MID
# 2                              []                          []          []
# 5                        [悪い, ない]  [見かける, 見る, 言う, 見る, 許す, 反応]    [愛想, 文句]
# 7    [直ぐ, 優しい, 真面目, 勤勉, 大人しい, 好き]                [怒る, 許す, する]      [インドア]
# 8                              []                          []       [ふつう]
# 11                             []                          []          []

# %%
# Create a new dataframe with each cell containing a length of the list of tokens
sentences_token_length = sentences_token_both.applymap(len)
sentences_token_length.head()
# Out:
# /tmp/ipykernel_1179/2820304063.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   sentences_token_length = sentences_token_both.applymap(len)
#      Adj_self  Verb_self  Noun_self  Adj_target  Verb_target  Noun_target
# MID
# 2           0          1          1           0            0            0
# 5           0          2          1           2            6            2
# 7           2          8          7           6            3            1
# 8           0          0          1           0            0            1
# 11          2          4          3           0            0            0

# %%
# Add the 'missing' column from the df_cosine dataframe with the 'sentences_token_length' dataframe
sentences_token_length['missing'] = df_cosine['missing']
sentences_token_length.head()
# Out:
#      Adj_self  Verb_self  Noun_self  Adj_target  Verb_target  Noun_target  \
# MID
# 2           0          1          1           0            0            0
# 5           0          2          1           2            6            2
# 7           2          8          7           6            3            1
# 8           0          0          1           0            0            1
# 11          2          4          3           0            0            0
#
#      missing
# MID
# 2       True
# 5       True
# 7      False
# 8       True
# 11      True

# %%
df_ismissing = pd.DataFrame()
df_ismissing['missing'] = df_cosine['missing']
df_ismissing['Adj_Verb_missing'] = (sentences_token_length['Adj_self'] * sentences_token_length['Adj_target'] * 
                                    sentences_token_length['Verb_self'] * sentences_token_length['Verb_target']) == 0
df_ismissing.head()
# Out:
#      missing  Adj_Verb_missing
# MID
# 2       True              True
# 5       True              True
# 7      False             False
# 8       True              True
# 11      True              True

# %%
matrix = pd.crosstab(df_ismissing['missing'], df_ismissing['Adj_Verb_missing'])
matrix
# Out:
# Adj_Verb_missing  False  True
# missing
# False               194      0
# True                  2    207

# %%
sentences_token_both[(df_ismissing['missing'] == True) & (df_ismissing['Adj_Verb_missing'] == False)]
# Out:
#      Adj_self    Verb_self             Noun_self Adj_target  \
# MID
# 341  [いい, いい]  [おもう, かんじる]                    []       [いい]
# 550      [積極]    [する, 分かる]  [相手, 八方美人, 目, 気, 社交]      [能無し]
#
#             Verb_target   Noun_target
# MID
# 341              [かんじる]            []
# 550  [発達, 使える, 媚びる, 売る]  [障害, ゴマ, スリ]

# %% [markdown]
# ## Evaluate the Missing Values

# %% [markdown]
# ### Test of Independence: Missing vs. IOS group

# %%
# Compare the number of the occurrences of the missing values with respect to the 'IOS_group' column
crosstab_iosgroup = pd.crosstab(df_cosine['missing'], df_cosine['IOS_group'])
crosstab_iosgroup
# Out:
# IOS_group  HighIOS  LowIOS
# missing
# False           92     102
# True           111      98

# %%
# Chi-square test of independence for the 'IOS_group' and 'missing' columns
chi2, p, dof, expected = stats.chi2_contingency(crosstab_iosgroup)
print(f"Chi2: {chi2}")
print(f"p-value: {p}")
print(f"Degrees of freedom: {dof}")
# Out:
# Chi2: 1.0842485666404802
# p-value: 0.29774906312971233
# Degrees of freedom: 1

# %% [markdown]
# ### Test of Independence: Missing vs. IOS score

# %%
crosstab_iosscore = pd.crosstab(df_cosine['missing'], df_cosine['IOS_score'])
crosstab_iosscore
# Out:
# IOS_score   1   2   3   5   6   7
# missing
# False      34  36  32  28  35  29
# True       31  39  28  37  37  37

# %%
# Chi-square test of independence for the 'IOS_score' and 'missing' columns
chi2, p, dof, expected = stats.chi2_contingency(crosstab_iosscore)
print(f"Chi2: {chi2}")
print(f"p-value: {p}")
print(f"Degrees of freedom: {dof}")
# Out:
# Chi2: 2.2413270362082804
# p-value: 0.8148445762746928
# Degrees of freedom: 5

# %% [markdown]
# ### Test of Independence: Missing vs. Self_Sex

# %%
# Crosstab with the missing values and the 'self_sex' column
crosstab_self_sex = pd.crosstab(df_cosine['missing'], df_cosine['self_sex'])
crosstab_self_sex
# Out:
# self_sex    1   2  4
# missing
# False     101  93  0
# True      114  92  3

# %%
# Chi-square test of independence for the 'self_sex'
chi2, p, dof, expected = stats.chi2_contingency(crosstab_self_sex)
print(f"Chi2: {chi2}")
print(f"p-value: {p}")
print(f"Degrees of freedom: {dof}")
# Out:
# Chi2: 3.2376246386416874
# p-value: 0.1981338791767277
# Degrees of freedom: 2

# %% [markdown]
# ### Mann-Whitney U test (a.k.a. Wilcoxon rank-sum test): Self_age between Missing vs. Not-Missing

# %%
from scipy.stats import mannwhitneyu

# Extract self_age for missing and not-missing groups
self_age_missing = df_cosine[df_cosine['missing']]['self_age']
self_age_not_missing = df_cosine[~df_cosine['missing']]['self_age']

# Perform the Mann-Whitney U test
stat, p = mannwhitneyu(self_age_missing, self_age_not_missing)

# Print the result
print(f'Mann-Whitney U test statistic: {stat}, p-value: {p}')

# Interpret the p-value
alpha = 0.05  # Typical threshold of significance
if p > alpha:
    print('No significant difference between HighIOS and LowIOS groups (fail to reject H0)')
else:
    print('Significant difference between HighIOS and LowIOS groups (reject H0)')
# Out:
# Mann-Whitney U test statistic: 18600.0, p-value: 0.15192495606885992
# No significant difference between HighIOS and LowIOS groups (fail to reject H0)

# %%
# The descriptive statistics of the 'self_age' column with respect to the 'missing' column, grouped by the 'IOS_group' and 'self_sex' columns
df_cosine.groupby(['missing'])['self_age'].describe()
# Out:
#          count       mean       std   min   25%   50%   75%   max
# missing
# False    194.0  48.195876  8.462828  24.0  43.0  50.0  55.0  59.0
# True     209.0  46.784689  9.194823  21.0  40.0  49.0  54.0  59.0

# %%
# Step 1: Combine Columns
df_cosine['self_sex_str'] = df_cosine['self_sex'].map({1: 'male', 2: 'female', 4: 'not to say'})
df_cosine['group_sex'] = df_cosine['IOS_group'] + '-' + df_cosine['self_sex_str']
# Step 2: Create the Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='group_sex', y='self_age', hue='missing', data=df_cosine, palette="Set3")
# Step 3: Customize the Plot
plt.title('Boxplot of Self Age by Missing Status')
plt.ylabel('Self Age')
plt.legend(title='Missing Status', bbox_to_anchor=(1.05, 1), loc='upper left')
# Step 4: Show the Plot
plt.tight_layout()  # Adjust layout to make room for the legend
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### Man-Whitney U test: RT between Missing vs. Not-Missing

# %%
from scipy.stats import mannwhitneyu

# Assuming df is your DataFrame and it has 'group' and 'IOS_score' columns
# Extract IOS_score for HighIOS and LowIOS groups
rt_missing = df_cosine[df_cosine['missing']]['rt']
rt_not_missing = df_cosine[~df_cosine['missing']]['rt']

# Perform the Mann-Whitney U test
stat, p = mannwhitneyu(rt_missing, rt_not_missing)

# Print the result
print(f'Mann-Whitney U test statistic: {stat}, p-value: {p}')

# Interpret the p-value
alpha = 0.05  # Typical threshold of significance
if p > alpha:
    print('No significant difference between HighIOS and LowIOS groups (fail to reject H0)')
else:
    print('Significant difference between HighIOS and LowIOS groups (reject H0)')
# Out:
# Mann-Whitney U test statistic: 10094.5, p-value: 2.9993280318653453e-18
# Significant difference between HighIOS and LowIOS groups (reject H0)

# %%
df_cosine.groupby(['missing'])['rt'].describe()
# Out:
#          count         mean           std   min     25%    50%     75%  \
# missing
# False    194.0  1730.474227   8146.884172  89.0  280.25  440.0  740.75
# True     209.0  1921.755981  16536.664234  76.0  155.00  226.0  360.00
#
#               max
# missing
# False     89172.0
# True     227706.0

# %%
# Step 2: Create the Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='group_sex', y='rt', hue='missing', data=df_cosine, palette="Set3")
# Step 3: Customize the Plot
plt.title('Boxplot of Reaction Time by Missing Status')
plt.ylabel('Reaction Time')
plt.legend(title='Missing Status', bbox_to_anchor=(1.05, 1), loc='upper left')
# Step 4: Show the Plot
plt.tight_layout()  # Adjust layout to make room for the legend
plt.yscale('log')
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Boxplot of the 'rt' column with respect to the 'missing' column
plt.figure(figsize=(10, 6))
plt.title('Boxplot of Reaction Time by Missing Status')
sns.boxplot(x='missing', y='rt', data=df_cosine, palette="Set3")
plt.ylabel('Reaction Time')
plt.legend(title='Missing Status', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.yscale('log')
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Data Profile

# %%
# Drop rows with missing value(s)
df_cosine = df_cosine.dropna()
print(f"The number of the ramaining observations: {len(df_cosine)}")
df_cosine.head()
# Out:
# The number of the ramaining observations: 194
#         rt  self_sex  self_age  target_likedislike  target_sex  IOS_score  \
# MID
# 7    293.0         1        54                   1           2          5
# 44   156.0         1        53                   4           2          5
# 47   286.0         2        49                   1           2          1
# 64   454.0         2        47                   2           1          3
# 66   457.0         2        55                   2           1          5
#
#     IOS_group  Adj_cosine  Verb_cosine  missing self_sex_str       group_sex
# MID
# 7     HighIOS    0.489526     0.826740    False         male    HighIOS-male
# 44    HighIOS    0.608727     0.293749    False         male    HighIOS-male
# 47     LowIOS    0.343798     0.767628    False       female   LowIOS-female
# 64     LowIOS    0.580847     0.837091    False       female   LowIOS-female
# 66    HighIOS    0.557176     0.751485    False       female  HighIOS-female

# %%
# Add a new column where the target_likedislike is converted to a binary variable (0: dislike, 1: like)
df_cosine.loc[:, 'target_likedislike_binary'] = np.where(df_cosine['target_likedislike'] < 4, 'like', 'dislike')
# The number of occurrences of each value in the IOS_group column with respect to the target_likedislike_binary
print(df_cosine.groupby('target_likedislike_binary')['IOS_score'].value_counts())
# The count plot of the IOS_group column with respect to the target_likedislike_binary
sns.countplot(x='IOS_score', hue='target_likedislike_binary', data=df_cosine)
# Out:
# target_likedislike_binary  IOS_score
# dislike                    1            19
#                            2            18
#                            3            18
#                            6            15
#                            5            13
#                            7             8
# like                       7            21
#                            6            20
#                            2            18
#                            1            15
#                            5            15
#                            3            14
# Name: count, dtype: int64
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='IOS_score', ylabel='count'>

# %% [markdown]
# ## Demographic Information

# %%
# The descriptive statistics of self_age with respect to the IOS_group and self_sex
df_cosine.groupby(['IOS_group', 'self_sex'])['self_age'].describe()
# Out:
#                     count       mean       std   min    25%   50%   75%   max
# IOS_group self_sex
# HighIOS   1          50.0  48.780000  8.706765  24.0  44.00  51.5  56.0  59.0
#           2          42.0  46.404762  8.593984  27.0  42.25  48.0  54.0  58.0
# LowIOS    1          51.0  50.529412  7.100290  33.0  46.00  52.0  57.0  59.0
#           2          51.0  46.764706  8.972376  24.0  41.00  49.0  53.5  59.0

# %%
# Add a new column for whether the self_sex differs from the target_sex
df_cosine.loc[:, 'diff_sex'] = df_cosine['self_sex'] != df_cosine['target_sex']
# The count of occurrence of each value in the diff_sex with the respect of the IOS_group
df_cosine.groupby('IOS_group')['diff_sex'].value_counts()
# Out:
# IOS_group  diff_sex
# HighIOS    True        71
#            False       21
# LowIOS     True        65
#            False       37
# Name: count, dtype: int64

# %% [markdown]
# ## Completion Time

# %%
# The descriptive statistics of rt with respect to IOS_group
print(df_cosine.groupby('IOS_group')['rt'].describe())
# The boxplot of rt with respect to IOS_group
sns.boxplot(x='IOS_group', y='rt', data=df_cosine, order=['HighIOS', 'LowIOS'])
plt.yscale('log')
plt.show()
# Out:
#            count         mean           std    min     25%    50%     75%  \
# IOS_group
# HighIOS     92.0  2718.543478  11547.814130   89.0  258.50  408.5  711.75
# LowIOS     102.0   839.274510   2233.585379  106.0  309.75  451.5  751.50
#
#                max
# IOS_group
# HighIOS    89172.0
# LowIOS     22147.0
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Mann-Whitney U test for the rt column with respect to the IOS_group
rt_highios = df_cosine[df_cosine['IOS_group'] == 'HighIOS']['rt']
rt_lowios = df_cosine[df_cosine['IOS_group'] == 'LowIOS']['rt']
mannwhitneyu(rt_highios, rt_lowios)
# Out:
# MannwhitneyuResult(statistic=4088.5, pvalue=0.12254231190599578)

# %%
# T-test for the rt column with respect to the IOS_group
# t_stat, p = stats.ttest_ind(rt_highios, rt_lowios)
# print(f'T-test statistic: {t_stat}, p-value: {p}')
stats.ttest_ind(rt_highios, rt_lowios)
# Out:
# TtestResult(statistic=1.6109343479429132, pvalue=0.10883675306711944, df=192.0)

# %% [markdown]
# ## Primary Outcomes (Similarity: Adjectives and Verbs)

# %%
# The descriptive statistics of the Adj_cosine column with respect to the IOS_group
df_cosine.groupby('IOS_group')['Adj_cosine'].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# IOS_group
# HighIOS     92.0  0.627539  0.211875  0.076658  0.477442  0.666246  0.792873
# LowIOS     102.0  0.625654  0.217492  0.076291  0.492899  0.662165  0.790230
#
#            max
# IOS_group
# HighIOS    1.0
# LowIOS     1.0

# %%
# The descriptive statistics of the Verb_cosine column with respect to the IOS_group
df_cosine.groupby('IOS_group')['Verb_cosine'].describe()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# IOS_group
# HighIOS     92.0  0.719144  0.200225  0.146441  0.637303  0.769811  0.865895
# LowIOS     102.0  0.672131  0.224204 -0.017176  0.559400  0.731393  0.835116
#
#                 max
# IOS_group
# HighIOS    1.000000
# LowIOS     0.962621

# %%
# Create a figure with three subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Plot the histogram for Adj_cosine
axes[0].hist(df['Adj_cosine'][df['IOS_group'] == 'HighIOS'], bins=10, alpha=0.5, label='HighIOS')
axes[0].hist(df['Adj_cosine'][df['IOS_group'] == 'LowIOS'], bins=10, alpha=0.5, label='LowIOS')
axes[0].set_xlabel('Adj_cosine')
axes[0].set_ylabel('Frequency')
axes[0].legend()

# Plot the histogram for Verb_cosine
axes[1].hist(df['Verb_cosine'][df['IOS_group'] == 'HighIOS'], bins=10, alpha=0.5, label='HighIOS')
axes[1].hist(df['Verb_cosine'][df['IOS_group'] == 'LowIOS'], bins=10, alpha=0.5, label='LowIOS')
axes[1].set_xlabel('Verb_cosine')
axes[1].set_ylabel('Frequency')
axes[1].legend()

# # Plot the histogram for Noun_cosine
# axes[2].hist(df['Noun_cosine'][df['IOS_group'] == 'HighIOS'], bins=10, alpha=0.5, label='HighIOS')
# axes[2].hist(df['Noun_cosine'][df['IOS_group'] == 'LowIOS'], bins=10, alpha=0.5, label='LowIOS')
# axes[2].set_xlabel('Noun_cosine')
# axes[2].set_ylabel('Frequency')
# axes[2].legend()

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Visualizing Data Distribution

# %% [markdown]
# ## Boxplot

# %%
# melt_df = df_cosine.melt(id_vars=['IOS_group'], value_vars=['Adj_cosine', 'Verb_cosine', 'Noun_cosine'], var_name='Type', value_name='Cosine_similarity')
melt_df = df_cosine.melt(id_vars=['IOS_group'], value_vars=['Adj_cosine', 'Verb_cosine'], var_name='Type', value_name='Cosine_similarity')
# create a boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='Cosine_similarity', data=melt_df, hue='IOS_group')
plt.ylim(0, 1.2)
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Assumption Check

# %% [markdown]
# ## Adequate sample size assumption

# %%
# The number of samples in the HighIOS and LowIOS groups for the Adj_cosine column
print(df_cosine.groupby('IOS_group')['Adj_cosine'].count())
# The number of samples in the HighIOS and LowIOS groups for the Verb_cosine column
print(df_cosine.groupby('IOS_group')['Verb_cosine'].count())
# Out:
# IOS_group
# HighIOS     92
# LowIOS     102
# Name: Adj_cosine, dtype: int64
# IOS_group
# HighIOS     92
# LowIOS     102
# Name: Verb_cosine, dtype: int64

# %% [markdown]
# The number of the observations in each cell was larger than the number of outcome variables.

# %% [markdown]
# ## Independency of observations

# %%
# Replace 'HighIOS' with 1 and 'LowIOS' with 0 in the 'IOS_group' column
df_cosine['IOS_group'] = df_cosine['IOS_group'].replace({'HighIOS': 1, 'LowIOS': 0}).astype(int)

# %%
# ADJ_COSINE
md = smf.mixedlm("Adj_cosine ~ C(1|IOS_group)", df_cosine, groups=df_cosine["IOS_group"])
mdf = md.fit(reml=True)
print(mdf.summary())
print("Residual Var: ", mdf.scale)
print("Group Var: ", mdf.cov_re.iloc[0, 0])
print('rho_adj:', mdf.cov_re.iloc[0, 0] / (mdf.cov_re.iloc[0, 0] + mdf.scale))
# Out:
#          Mixed Linear Model Regression Results
# ========================================================
# Model:            MixedLM Dependent Variable: Adj_cosine
# No. Observations: 194     Method:             REML
# No. Groups:       2       Scale:              0.0459
# Min. group size:  92      Log-Likelihood:     inf
# Max. group size:  102     Converged:          Yes
# Mean group size:  97.0
# ---------------------------------------------------------
#                Coef.   Std.Err.  z  P>|z|  [0.025  0.975]
# ---------------------------------------------------------
# Intercept      -1.773
# Group Var       0.000
# ========================================================
#
# Residual Var:  0.04592054995451486
# Group Var:  0.0
# rho_adj: 0.0
# /opt/conda/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2201: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:1635: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2055: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2246: UserWarning: The random effects covariance matrix is singular.
#   warnings.warn(_warn_cov_sing)
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2262: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2706: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %% [markdown]
# ICC of the Adj_cosine (0.0) was much less than 0.05 (small effect: Hox, 2010)

# %%
# Verb_cosine
md = smf.mixedlm("Verb_cosine ~ C(1|IOS_group)", df_cosine, groups=df_cosine["IOS_group"])
mdf = md.fit(reml=True)
print(mdf.summary())
print("Residual Var: ", mdf.scale)
print("Group Var: ", mdf.cov_re.iloc[0, 0])
print('rho_verb:', mdf.cov_re.iloc[0, 0] / (mdf.cov_re.iloc[0, 0] + mdf.scale))
# Out:
# /opt/conda/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#           Mixed Linear Model Regression Results
# =========================================================
# Model:            MixedLM Dependent Variable: Verb_cosine
# No. Observations: 194     Method:             REML
# No. Groups:       2       Scale:              0.0454
# Min. group size:  92      Log-Likelihood:     21.3915
# Max. group size:  102     Converged:          Yes
# Mean group size:  97.0
# ----------------------------------------------------------
#             Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# ----------------------------------------------------------
# Intercept   0.695     0.024  29.561  0.000   0.649   0.741
# Group Var   0.001     0.007
# =========================================================
#
# Residual Var:  0.04544376068612539
# Group Var:  0.0006356474713315368
# rho_verb: 0.013794610146889904

# %% [markdown]
# ICC of the Verb_cosine (0.01) was less than 0.05 (small effect: Hox, 2010)

# %% [markdown]
# ## Univariate outlier

# %%
# Find extreme outliers, which are above Q3 + 3*IQR or below Q1 - 3*IQR in the Adj_cosine column
Q1 = df['Adj_cosine'].quantile(0.25)
Q3 = df['Adj_cosine'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 3 * IQR
upper_bound = Q3 + 3 * IQR
extreme_outliers = df[(df['Adj_cosine'] < lower_bound) | (df['Adj_cosine'] > upper_bound)]
extreme_outliers
# Out:
# Empty DataFrame
# Columns: [rt, self_sex, self_age, target_likedislike, target_sex, IOS_score, IOS_group, Adj_cosine, Adj_euclidean, Adj_manhattan, Verb_cosine, Verb_euclidean, Verb_manhattan, Noun_cosine, Noun_euclidean, Noun_manhattan]
# Index: []

# %% [markdown]
# There were no univariate extreme outliers in the Adj_cosine, as assessed that values above Q3 + 3IQR or below Q1 - 3IQR

# %%
# Find extreme outliers, which are above Q3 + 3*IQR or below Q1 - 3*IQR in the Verb_cosine column
Q1 = df['Verb_cosine'].quantile(0.25)
Q3 = df['Verb_cosine'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 3 * IQR
upper_bound = Q3 + 3 * IQR
extreme_outliers = df[(df['Verb_cosine'] < lower_bound) | (df['Verb_cosine'] > upper_bound)]
extreme_outliers
# Out:
# Empty DataFrame
# Columns: [rt, self_sex, self_age, target_likedislike, target_sex, IOS_score, IOS_group, Adj_cosine, Adj_euclidean, Adj_manhattan, Verb_cosine, Verb_euclidean, Verb_manhattan, Noun_cosine, Noun_euclidean, Noun_manhattan]
# Index: []

# %% [markdown]
# There was no univariate extreme outliers in the Verb_cosine, as assessed that values above Q3 + 3IQR or below Q1 - 3IQR

# %% [markdown]
# ## Multivariate outliers

# %%
# Find extreme multivariate outliers using Mahalanobis distance
# The columns to be used for the Mahalanobis distance: Adj_cosine and Verb_cosine
X = df_cosine[['Adj_cosine', 'Verb_cosine']]
# The mean of the columns
mean = X.mean()
# The covariance matrix of the columns
cov = X.cov()
# The inverse of the covariance matrix
inv_cov = inv(cov)
# The Mahalanobis distance
mahalanobis = [distance.mahalanobis(row, mean, inv_cov) for row in X.itertuples(index=False)]
# The threshold for the Mahalanobis distance
threshold = stats.chi2.ppf(0.999, df=2)
# The multivariate outliers
multivariate_outliers = df_cosine[mahalanobis > threshold]
multivariate_outliers
# Out:
# Empty DataFrame
# Columns: [rt, self_sex, self_age, target_likedislike, target_sex, IOS_score, IOS_group, Adj_cosine, Verb_cosine, missing, self_sex_str, group_sex, target_likedislike_binary, diff_sex]
# Index: []

# %% [markdown]
# There were no multivariate extreme outliers in the data, as assessed by Mahalanobis distance (p > 0.001)

# %% [markdown]
# ## Univariate Normality

# %%
# QQ plot for the Adj_cosine column with respect to the IOS_group
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sm.qqplot(df_cosine[df_cosine['IOS_group'] == 1]['Adj_cosine'], line='45', ax=axs[0])
axs[0].set_title('QQ plot for Adj_cosine (HighIOS)')
sm.qqplot(df_cosine[df_cosine['IOS_group'] == 0]['Adj_cosine'], line='45', ax=axs[1])
axs[1].set_title('QQ plot for Adj_cosine (LowIOS)')
plt.tight_layout()
plt.show()

# %% [markdown]
# All the points did not fell along the reference line for each group. So we cannot assumy normality of the Adj_cosine distribution.

# %%
# QQ plot for the Verb_cosine column with respect to the IOS_group
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sm.qqplot(df_cosine[df_cosine['IOS_group'] == 1]['Verb_cosine'], line='45', ax=axs[0])
axs[0].set_title('QQ plot for Verb_cosine (HighIOS)')
sm.qqplot(df_cosine[df_cosine['IOS_group'] == 0]['Verb_cosine'], line='45', ax=axs[1])
axs[1].set_title('QQ plot for Verb_cosine (LowIOS)')
plt.tight_layout()
plt.show()

# %% [markdown]
# All the points did not fell along the reference line for each group. So we cannot assumy normality of the Verb_cosine distribution.
# Although the univariate normality assumptions were not met, MANOVA was performed since it is fairly robust to deviations from normality.

# %%
# Shapiro-Wilk test for the Adj_cosine column with respect to the IOS_group
# When the sample size is greater than 50, the Shapiro-Wilk test is not reliable
shapiro_adj = df_cosine.groupby('IOS_group')['Adj_cosine'].apply(lambda x: stats.shapiro(x))
shapiro_adj # W-statistic, p-value
# Out:
# IOS_group
# 0    (0.9598021507263184, 0.003458153223618865)
# 1    (0.9549921751022339, 0.003021637909114361)
# Name: Adj_cosine, dtype: object

# %%
# Shapiro-Wilk test for the Verb_cosine column with respect to the IOS_group
# When the sample size is greater than 50, the Shapiro-Wilk test is not reliable
shapiro_adj = df_cosine.groupby('IOS_group')['Verb_cosine'].apply(lambda x: stats.shapiro(x))
shapiro_adj # W-statistic, p-value
# Out:
# IOS_group
# 0    (0.9015504717826843, 1.3655919701704988e-06)
# 1     (0.8868033289909363, 8.676107654537191e-07)
# Name: Verb_cosine, dtype: object

# %%
# Assume df_cosine is your DataFrame and it has columns 'Adj_cosine', 'Verb_cosine', 'Noun_cosine', and 'IOS_group'
# sns.pairplot(df_cosine, vars=['Adj_cosine', 'Verb_cosine', 'Noun_cosine'], hue='IOS_group')
# Assume df_cosine is your DataFrame and it has columns 'Adj_cosine', 'Verb_cosine',  and 'IOS_group'
sns.pairplot(df_cosine, vars=['Adj_cosine', 'Verb_cosine'], hue='IOS_group')
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Multivariate Normality

# %%
# Create a Q-Q plot for multivariate normality by using Mahalanobis distance,
# which measures distance between a point and a distribution
 
# Assume df_cosine is your DataFrame and it has columns 'Adj_cosine', 'Verb_cosine', and 'Noun_cosine'
# X = df_cosine[['Adj_cosine', 'Verb_cosine', 'Noun_cosine']].values
# X = df_cosine[['Adj_cosine', 'Verb_cosine']].values

# Standardize the data
# X_std = StandardScaler().fit_transform(X)

# Calculate the Mahalanobis distance
# mahalanobis = np.sqrt((X_std**2).sum(axis=1))

# # Calculate the mean of the data
# mean = np.mean(X, axis=0)
# 
# # Calculate the covariance matrix
# cov = np.cov(X, rowvar=False)
# 
# # Calculate the inverse of the covariance matrix
# inv_cov = inv(cov)
# 
# # Calculate the Mahalanobis distance
# mahalanobis = np.array([distance.mahalanobis(x, mean, inv_cov) for x in X])

# Create Q-Q plot
sm.qqplot(np.array(mahalanobis), stats.chi2, distargs=(2,), line='45', fit=True) 
plt.show()

# %% [markdown]
# All the points fall approximately along the reference line. So multivariate normality can be assumed.

# %%
# The Shapiro-Wilk test to tell if a random sample comes from a normal distribution.
# The null hypothesis of the test is that the data are normally distributed.
# 
# The Shapiro-Wilk test is typically used to test the normality of univariate data.
# For multivariate data, you might want to consider using a multivariate normality test, such as the Henze-Zirkler's multivariate normality test provided by the `pingouin` package.
# However, if you still want to apply the Shapiro-Wilk test to each variable in your multivariate data, you can do so by iterating over the columns of your DataFrame. Here's how you can do it:

# Assume df_cosine is your DataFrame and it has columns 'Adj_cosine', 'Verb_cosine', and 'Noun_cosine'
# variables = ['Adj_cosine', 'Verb_cosine', 'Noun_cosine']
variables = ['Adj_cosine', 'Verb_cosine']

for var in variables:
    shapiro_test = stats.shapiro(df_cosine[var])
    print(f"Shapiro test for {var}: statistic={shapiro_test.statistic}, p-value={shapiro_test.pvalue}")
# Out:
# Shapiro test for Adj_cosine: statistic=0.9594340324401855, p-value=2.299559855600819e-05
# Shapiro test for Verb_cosine: statistic=0.8967142105102539, p-value=2.4525603770086946e-10

# %%
# The Henze-Zirkler's multivariate normality test

# Assume df_cosine is your DataFrame and it has columns 'Adj_cosine', 'Verb_cosine', 'Noun_cosine'
# X = df_cosine[['Adj_cosine', 'Verb_cosine', 'Noun_cosine']]
X = df_cosine[['Adj_cosine', 'Verb_cosine']]

# Perform multivariate normality test
result = pg.multivariate_normality(X)
print(result)
# Out:
# HZResults(hz=4.8422630730073335, pval=7.65599170451476e-11, normal=False)

# %% [markdown]
# ### Exclude Outliers

# %%
# Find the outliers using the Mahalanobis distance
mahalanobis = np.array(mahalanobis)
outliers = mahalanobis > np.percentile(mahalanobis, 90) # compute the q-th percentile of the data along the specified axis
print(f"The number of outliers: {outliers.sum()}")
print(f"The indices of the outliers: {np.where(outliers)}")
# Out:
# The number of outliers: 20
# The indices of the outliers: (array([ 13,  16,  20,  32,  43,  54,  59,  68,  71,  78,  84,  89,  93,
#         99, 113, 117, 118, 152, 164, 176]),)

# %%
# Access to the outliers
df_cosine_outliers = df_cosine[outliers]
df_cosine_outliers.head(10)
# Out:
#         rt  self_sex  self_age  target_likedislike  target_sex  IOS_score  \
# MID
# 143  147.0         2        27                   1           1          6
# 161  670.0         2        45                   1           1          3
# 192  439.0         1        57                   2           2          5
# 235  714.0         2        58                   6           1          1
# 275  475.0         2        49                   3           2          1
# 319  280.0         2        51                   2           2          2
# 329  289.0         2        36                   4           4          2
# 359  495.0         2        58                   2           1          6
# 391  273.0         2        32                   1           1          7
# 424  106.0         2        33                   1           1          3
#
#      IOS_group  Adj_cosine  Verb_cosine  missing self_sex_str       group_sex  \
# MID
# 143          1    0.382834     0.146631    False       female  HighIOS-female
# 161          0    0.369436     0.175636    False       female   LowIOS-female
# 192          1    0.732794     0.206402    False         male    HighIOS-male
# 235          0    0.917169     0.304145    False       female   LowIOS-female
# 275          0    0.218479     0.907539    False       female   LowIOS-female
# 319          0    0.828454     0.130645    False       female   LowIOS-female
# 329          0    0.578970     0.093264    False       female   LowIOS-female
# 359          1    0.141937     0.647173    False       female  HighIOS-female
# 391          1    0.255386     0.915148    False       female  HighIOS-female
# 424          0    0.696794     0.102989    False       female   LowIOS-female
#
#     target_likedislike_binary  diff_sex
# MID
# 143                      like      True
# 161                      like      True
# 192                      like      True
# 235                   dislike      True
# 275                      like     False
# 319                      like     False
# 329                   dislike      True
# 359                      like      True
# 391                      like      True
# 424                      like      True

# %%
# Create Q-Q plot without outliers
sm.qqplot(mahalanobis[~outliers], stats.chi2, distargs=(2,), line='45', fit=True) 
plt.show()

# %%
# The Henze-Zirkler's multivariate normality test with outliers removed
# Data without outliers
X_norm = df_cosine[['Adj_cosine', 'Verb_cosine']][~outliers]
# Perform multivariate normality test
result = pg.multivariate_normality(X_norm)
print(result)
# Out:
# HZResults(hz=2.8750043234613543, pval=8.405463258898336e-07, normal=False)

# %% [markdown]
# ## Multicollinearity

# %%
# Pairwise Pearson correlation between the Adj_cosine and Verb_cosine columns
df_cosine[['Adj_cosine', 'Verb_cosine']].corr()
# Out:
#              Adj_cosine  Verb_cosine
# Adj_cosine     1.000000     0.258892
# Verb_cosine    0.258892     1.000000

# %%
# Significance of the correlation coefficient
# The number of observations
n = len(df_cosine)
# The correlation coefficient
r = df_cosine['Adj_cosine'].corr(df_cosine['Verb_cosine'])
# The degrees of freedom
df = n - 2
# The t-statistic
t = r * np.sqrt(df / (1 - r**2))
# The p-value
p = 2 * (1 - stats.t.cdf(t, df))
# Result
print(f"There was no multicollinearity, as assessed by the Pearson correlation coefficient (r = {r}, t = {t}, df = {df}, p = {p}).")
# Out:
# There was no multicollinearity, as assessed by the Pearson correlation coefficient (r = 0.258892161769465, t = 3.7139371348195076, df = 192, p = 0.00026740275120284984).

# %% [markdown]
# ## Linearity between all the outcomes for each group

# %%
# Pairplots with the correlation coefficient for the HighIOS and LowIOS groups
sns.pairplot(df_cosine, vars=['Adj_cosine', 'Verb_cosine'], hue='IOS_group')
plt.show()
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Correlation matrix for Adj_cosine, Verb_cosine, and Noun_cosine of HighIOS and LowIOS
df_cosine.groupby('IOS_group')[['Adj_cosine', 'Verb_cosine']].corr()
# Out:
#                        Adj_cosine  Verb_cosine
# IOS_group
# HighIOS   Adj_cosine     1.000000     0.163192
#           Verb_cosine    0.163192     1.000000
# LowIOS    Adj_cosine     1.000000     0.336294
#           Verb_cosine    0.336294     1.000000

# %%
# Statistical test for the correlation between Adj_cosine and Verb_cosine for the HighIOS and LowIOS groups, respectively
# HighIOS
r_highios = df_cosine[df_cosine['IOS_group'] == 1]['Adj_cosine'].corr(df_cosine[df_cosine['IOS_group'] == 1]['Verb_cosine'])
# Test
t_stat, p = stats.ttest_ind(df_cosine[df_cosine['IOS_group'] == 1]['Adj_cosine'], df_cosine[df_cosine['IOS_group'] == 1]['Verb_cosine'])
print(f'HighIOS: r={r_highios}, t={t_stat}, p={p}')
# LowIOS
r_lowios = df_cosine[df_cosine['IOS_group'] == 0]['Adj_cosine'].corr(df_cosine[df_cosine['IOS_group'] == 0]['Verb_cosine'])
# Test
t_stat, p = stats.ttest_ind(df_cosine[df_cosine['IOS_group'] == 0]['Adj_cosine'], df_cosine[df_cosine['IOS_group'] == 0]['Verb_cosine'])
print(f'LowIOS: r={r_lowios}, t={t_stat}, p={p}')
# Out:
# HighIOS: r=0.1631917663757963, t=-3.0140740928766796, p=0.002945440534483421
# LowIOS: r=0.3362944878353289, t=-1.5027426654032547, p=0.13446712283470422

# %% [markdown]
# There was a linear relationship between the Adj_cosine and Verb_cosine in each IOS group, as assessed by scatter plot (r=0.16 in the High IOS; r=0.34 in the Low IOS).

# %% [markdown]
# ## Homogeneity of variance for each variable

# %%
# Levene's test for the equality of variances between the HighIOS and LowIOS groups for the Adj_cosine column
stats.levene(df_cosine[df_cosine['IOS_group'] == 1]['Adj_cosine'], df_cosine[df_cosine['IOS_group'] == 0]['Adj_cosine'])
# Out:
# LeveneResult(statistic=0.014555749073530213, pvalue=0.9040966350516565)

# %%
# Levene's test for the equality of variances between the HighIOS and LowIOS groups for the Verb_cosine column
stats.levene(df_cosine[df_cosine['IOS_group'] == 1]['Verb_cosine'], df_cosine[df_cosine['IOS_group'] == 0]['Verb_cosine'])
# Out:
# LeveneResult(statistic=0.7748684628479665, pvalue=0.379815638283147)

# %% [markdown]
# The Levene's test for each of the outcome variables was not significant, so there was equal variances between groups in each outcome variables.

# %% [markdown]
# ## Homogeneity of covariance matrices

# %%
# The Box's M test to examine the homogeneity of covariance matrices across groups.
# The null hypothesis of the test is that the covariance matrices are equal across groups.

# Perform Box's M test
# result = pg.multivariate.box_m(data=df_cosine, dvs=['Adj_cosine', 'Verb_cosine', 'Noun_cosine'], group='IOS_group')
result = pg.multivariate.box_m(data=df_cosine, dvs=['Adj_cosine', 'Verb_cosine'], group='IOS_group', alpha=0.001)
result
# Out:
#          Chi2   df      pval  equal_cov
# box  2.396093  3.0  0.494362       True

# %% [markdown]
# The Box's M test revealed the homogeneity of the variance-covariance matrices.

# %% [markdown]
# # MANOVA

# %%
# MANOVA for Adj_cosine, Verb_cosine, Noun_cosine
# maov_cosine = MANOVA.from_formula('Adj_cosine + Verb_cosine + Noun_cosine ~ IOS_group', data=df_cosine[['IOS_group', 'Adj_cosine', 'Verb_cosine', 'Noun_cosine']])
maov_cosine = MANOVA.from_formula('Adj_cosine + Verb_cosine ~ IOS_group', data=df_cosine[['IOS_group', 'Adj_cosine', 'Verb_cosine']])
print(maov_cosine.mv_test())
# Out:
#                   Multivariate linear model
# ==============================================================
#
# --------------------------------------------------------------
#        Intercept        Value  Num DF  Den DF  F Value  Pr > F
# --------------------------------------------------------------
#           Wilks' lambda 0.1163 2.0000 191.0000 725.7710 0.0000
#          Pillai's trace 0.8837 2.0000 191.0000 725.7710 0.0000
#  Hotelling-Lawley trace 7.5997 2.0000 191.0000 725.7710 0.0000
#     Roy's greatest root 7.5997 2.0000 191.0000 725.7710 0.0000
# --------------------------------------------------------------
#
# --------------------------------------------------------------
#         IOS_group        Value  Num DF  Den DF  F Value Pr > F
# --------------------------------------------------------------
#            Wilks' lambda 0.9873 2.0000 191.0000  1.2310 0.2943
#           Pillai's trace 0.0127 2.0000 191.0000  1.2310 0.2943
#   Hotelling-Lawley trace 0.0129 2.0000 191.0000  1.2310 0.2943
#      Roy's greatest root 0.0129 2.0000 191.0000  1.2310 0.2943
# ==============================================================

# %%
maov_cosine.mv_test().results
# Out:
# {'Intercept': {'stat':                            Value Num DF Den DF     F Value Pr > F
#   Wilks' lambda           0.116283      2  191.0  725.770983    0.0
#   Pillai's trace          0.883717    2.0  191.0  725.770983    0.0
#   Hotelling-Lawley trace  7.599696      2  191.0  725.770983    0.0
#   Roy's greatest root     7.599696      2    191  725.770983    0.0,
#   'contrast_L': array([[1., 0.]]),
#   'transform_M': array([[1., 0.],
#          [0., 1.]]),
#   'constant_C': array([[0., 0.]]),
#   'E': array([[8.86266614, 2.28625366],
#          [2.28625366, 8.72521371]]),
#   'H': array([[36.23003031, 41.51874065],
#          [41.51874065, 47.5794751 ]])},
#  'IOS_group': {'stat':                            Value Num DF Den DF   F Value  Pr > F
#   Wilks' lambda           0.987274      2  191.0  1.231021  0.2943
#   Pillai's trace          0.012726    2.0  191.0  1.231021  0.2943
#   Hotelling-Lawley trace   0.01289      2  191.0  1.231021  0.2943
#   Roy's greatest root      0.01289      2    191  1.231021  0.2943,
#   'contrast_L': array([[0., 1.]]),
#   'transform_M': array([[1., 0.],
#          [0., 1.]]),
#   'constant_C': array([[0., 0.]]),
#   'E': array([[8.86266614, 2.28625366],
#          [2.28625366, 8.72521371]]),
#   'H': array([[0.00017185, 0.00428638],
#          [0.00428638, 0.1069103 ]])}}

# %% [markdown]
# There was no significant difference between the High IOS and the Low IOS groups on the combined dependent variables (Wilk's Lambda = 0.987, df1=2, df2=191, F=1.23, p=0.29)
